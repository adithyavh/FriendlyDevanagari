# %%
from utils import DevanagariString

DevanagariString("वद")+"ान्"+"मि"
# Out:
# वदान्मि

# %%
from verbs import DhaturupaThematic, Plurality, Person, VerbClass
from verbs_data import MODEL_WORDS_1P

# %%
for model_word in MODEL_WORDS_1P:

    verb = DhaturupaThematic(model_word, VerbClass.Class1P)

    print (f"{MODEL_WORDS_1P[model_word][0]} ({MODEL_WORDS_1P[model_word][1]} -> {model_word})")
    print ("-")

    for plurality in Plurality._member_names_:
        for person in Person._member_names_:
            print(f"{plurality}\t{person}\t:", verb.generatePresent(Plurality[plurality], Person[person]))

    print ("_________________________")
# Out:
# speak (वद् -> वद्)
# -
# Singular	First	: वदामि
# Singular	Second	: वदसि
# Singular	Third	: वदति
# Dual	First	: वदावः
# Dual	Second	: वदथः
# Dual	Third	: वदतः
# Plural	First	: वदामः
# Plural	Second	: वदथ
# Plural	Third	: वदन्ति
# _________________________
# eat (खाद् -> खाद्)
# -
# Singular	First	: खादामि
# Singular	Second	: खादसि
# Singular	Third	: खादति
# Dual	First	: खादावः
# Dual	Second	: खादथः
# Dual	Third	: खादतः
# Plural	First	: खादामः
# Plural	Second	: खादथ
# Plural	Third	: खादन्ति
# _________________________
# abandon (त्यज् -> त्यज्)
# -
# Singular	First	: त्यजामि
# Singular	Second	: त्यजसि
# Singular	Third	: त्यजति
# Dual	First	: त्यजावः
# Dual	Second	: त्यजथः
# Dual	Third	: त्यजतः
# Plural	First	: त्यजामः
# Plural	Second	: त्यजथ
# Plural	Third	: त्यजन्ति
# _________________________
# win (जि -> जय्)
# -
# Singular	First	: जयामि
# Singular	Second	: जयसि
# Singular	Third	: जयति
# Dual	First	: जयावः
# Dual	Second	: जयथः
# Dual	Third	: जयतः
# Plural	First	: जयामः
# ...

# %%
for model_word in MODEL_WORDS_1P:

    verb = DhaturupaThematic(model_word, VerbClass.Class1P)

    print (f"{MODEL_WORDS_1P[model_word][0]} ({MODEL_WORDS_1P[model_word][1]} -> {model_word})")
    print ("-")

    for plurality in Plurality._member_names_:
        for person in Person._member_names_:
            print(f"{plurality}\t{person}\t:", verb.generatePastImperfect(Plurality[plurality], Person[person]))

    print ("_________________________")
# Out:
# speak (वद् -> वद्)
# -
# Singular	First	: अवदम्
# Singular	Second	: अवदः
# Singular	Third	: अवदत्
# Dual	First	: अवदाव
# Dual	Second	: अवदतम्
# Dual	Third	: अवदताम्
# Plural	First	: अवदाम
# Plural	Second	: अवदत
# Plural	Third	: अवदतन्
# _________________________
# eat (खाद् -> खाद्)
# -
# Singular	First	: अखादम्
# Singular	Second	: अखादः
# Singular	Third	: अखादत्
# Dual	First	: अखादाव
# Dual	Second	: अखादतम्
# Dual	Third	: अखादताम्
# Plural	First	: अखादाम
# Plural	Second	: अखादत
# Plural	Third	: अखादतन्
# _________________________
# abandon (त्यज् -> त्यज्)
# -
# Singular	First	: अत्यजम्
# Singular	Second	: अत्यजः
# Singular	Third	: अत्यजत्
# Dual	First	: अत्यजाव
# Dual	Second	: अत्यजतम्
# Dual	Third	: अत्यजताम्
# Plural	First	: अत्यजाम
# Plural	Second	: अत्यजत
# Plural	Third	: अत्यजतन्
# _________________________
# win (जि -> जय्)
# -
# Singular	First	: अजयम्
# Singular	Second	: अजयः
# Singular	Third	: अजयत्
# Dual	First	: अजयाव
# Dual	Second	: अजयतम्
# Dual	Third	: अजयताम्
# ...

# %%
for model_word in MODEL_WORDS_1P:

    verb = DhaturupaThematic(model_word, VerbClass.Class1P)

    print (f"{MODEL_WORDS_1P[model_word][0]} ({MODEL_WORDS_1P[model_word][1]} -> {model_word})")
    print ("-")

    for plurality in Plurality._member_names_:
        for person in Person._member_names_:
            print(f"{plurality}\t{person}\t:", verb.generateImperative(Plurality[plurality], Person[person]))

    print ("_________________________")
# Out:
# speak (वद् -> वद्)
# -
# Singular	First	: वदानि
# Singular	Second	: वद
# Singular	Third	: वदतु
# Dual	First	: वदाव
# Dual	Second	: वदतम्
# Dual	Third	: वदताम्
# Plural	First	: वदाम
# Plural	Second	: वदत
# Plural	Third	: वदन्तु
# _________________________
# eat (खाद् -> खाद्)
# -
# Singular	First	: खादानि
# Singular	Second	: खाद
# Singular	Third	: खादतु
# Dual	First	: खादाव
# Dual	Second	: खादतम्
# Dual	Third	: खादताम्
# Plural	First	: खादाम
# Plural	Second	: खादत
# Plural	Third	: खादन्तु
# _________________________
# abandon (त्यज् -> त्यज्)
# -
# Singular	First	: त्यजानि
# Singular	Second	: त्यज
# Singular	Third	: त्यजतु
# Dual	First	: त्यजाव
# Dual	Second	: त्यजतम्
# Dual	Third	: त्यजताम्
# Plural	First	: त्यजाम
# Plural	Second	: त्यजत
# Plural	Third	: त्यजन्तु
# _________________________
# win (जि -> जय्)
# -
# Singular	First	: जयानि
# Singular	Second	: जय
# Singular	Third	: जयतु
# Dual	First	: जयाव
# Dual	Second	: जयतम्
# Dual	Third	: जयताम्
# Plural	First	: जयाम
# ...

# %%
for model_word in MODEL_WORDS_1P:

    verb = Verb(model_word, VerbClass.Class1P)

    print (f"{MODEL_WORDS_1P[model_word][0]} ({MODEL_WORDS_1P[model_word][1]} -> {model_word})")
    print ("-")

    for plurality in Plurality._member_names_:
        for person in Person._member_names_:
            print(f"{plurality}\t{person}\t:", verb.generatePotential(Plurality[plurality], Person[person]))

    print ("_________________________")
# Out:
# speak (वद् -> वद्)
# -
# Singular	First	: वदेयम्
# Singular	Second	: वदे:
# Singular	Third	: वदेत
# Dual	First	: वदेव
# Dual	Second	: वदेतम्
# Dual	Third	: वदेताम्
# Plural	First	: वदेम
# Plural	Second	: वदेत
# Plural	Third	: वदेयुः
# _________________________
# eat (खाद् -> खाद्)
# -
# Singular	First	: खादेयम्
# Singular	Second	: खादे:
# Singular	Third	: खादेत
# Dual	First	: खादेव
# Dual	Second	: खादेतम्
# Dual	Third	: खादेताम्
# Plural	First	: खादेम
# Plural	Second	: खादेत
# Plural	Third	: खादेयुः
# _________________________
# abandon (त्यज् -> त्यज्)
# -
# Singular	First	: त्यजेयम्
# Singular	Second	: त्यजे:
# Singular	Third	: त्यजेत
# Dual	First	: त्यजेव
# Dual	Second	: त्यजेतम्
# Dual	Third	: त्यजेताम्
# Plural	First	: त्यजेम
# Plural	Second	: त्यजेत
# Plural	Third	: त्यजेयुः
# _________________________
# win (जि -> जय्)
# -
# Singular	First	: जयेयम्
# Singular	Second	: जये:
# Singular	Third	: जयेत
# Dual	First	: जयेव
# Dual	Second	: जयेतम्
# Dual	Third	: जयेताम्
# ...

# %%
model_word = "नृत्"

verb = DhaturupaThematic(model_word, VerbClass.Class4P)

for plurality in Plurality._member_names_:
    for person in Person._member_names_:
        print(f"{plurality}\t{person}\t:", verb.generatePastImperfect(Plurality[plurality], Person[person]))
# Out:
# Singular	First	: अनृत्यम्
# Singular	Second	: अनृत्यः
# Singular	Third	: अनृत्यत्
# Dual	First	: अनृत्याव
# Dual	Second	: अनृत्यतम्
# Dual	Third	: अनृत्यताम्
# Plural	First	: अनृत्याम
# Plural	Second	: अनृत्यत
# Plural	Third	: अनृत्यतन्

# %%
MODEL_WORDS_1P = { # model: (meaning, root)
        'वद्': ('speak', 'वद्'),
        'खाद्': ('eat', 'खाद्'),
        'त्यज्': ('abandon', 'त्यज्'),
        'जय्': ('win', 'जि'),
        'धाव्': ('run', 'धाव्'),
        'गच्छ्': ('go', 'गम्'),
        'सीद्': ('sit', 'सद्'),
        'पिब्': ('drink', 'पा'),
        'तिष्ट्': ('stand', 'स्था'),
        'पश्य्': ('see', 'दृश्'),
        'स्मर्': ('remember', 'स्मृ'),
        'नय': ('lead', 'नी'),
        'भव्': ('be/become', 'भू'),
        'बोध्': ('understand', 'बुध्'),
        'वस्': ('live', 'वस्'),
        'पत्': ('fall', 'पत्')
    }

for modelWord in MODEL_WORDS_1P:
    print (f"{modelWord}, {MODEL_WORDS_1P[modelWord][0]}, {MODEL_WORDS_1P[modelWord][1]}, 1P")
# Out:
# वद्, speak, वद्, 1P
# खाद्, eat, खाद्, 1P
# त्यज्, abandon, त्यज्, 1P
# जय्, win, जि, 1P
# धाव्, run, धाव्, 1P
# गच्छ्, go, गम्, 1P
# सीद्, sit, सद्, 1P
# पिब्, drink, पा, 1P
# तिष्ट्, stand, स्था, 1P
# पश्य्, see, दृश्, 1P
# स्मर्, remember, स्मृ, 1P
# नय, lead, नी, 1P
# भव्, be/become, भू, 1P
# बोध्, understand, बुध्, 1P
# वस्, live, वस्, 1P
# पत्, fall, पत्, 1P

# %%
"न" + "ैष"
# Out:
# 'नैष'
